# %% [markdown]
# # Demo SingleRun
# This notebook shows a single run consisting of the following four phases:
# * sail empty
# * loading
# * sail full
# * unloading

# %%
import datetime, time
import simpy

import shapely.geometry
from simplekml import Kml, Style

import pandas as pd
import openclsim.core as core
import openclsim.model as model
import openclsim.plot as plot
import openclsim.plugins as plugin

from plot import vessel_planning


import matplotlib.pyplot as plt
# %matplotlib inline

# setup environment
simulation_start  = datetime.datetime(2020,3,1)
my_env = simpy.Environment(initial_time=simulation_start.timestamp())
registry = {}
keep_resources = {}

import numpy as np

# %%
#Set limits
loading_limit = 2.0 
installing_limit = 1.5
sailing_empty_limit = 2.5
sailing_full_limit = 1.0

#Set durations (in hours)
loading_duration = 6
installing_duration = 8

#Set sailing speeds
sailing_speed_empty = 3
sailing_speed_full = 2

#Set amount of monopiles to install
amount_MP_to_install = 20

#Set amount of monopiles that Aeolus can hold
capacity_aeolus = 2

# %%
Site = type(
    "Site",
    (
        core.Identifiable,
        core.Log,
        core.Locatable,
        core.HasContainer,
        core.HasResource,
    ),
    {},
)

TransportProcessingResource = type(
    "TransportProcessingResource",
    (
        core.Identifiable,
        core.Log,
        core.ContainerDependentMovable,
        core.Processor,
        core.HasResource,
    ),
    {},
)

TestMoveActivity =  type(
    "TestMoveActivity",
    (
        plugin.HasWeatherPluginMoveActivity,
        model.MoveActivity,  # the order is critical!
    ),
    {},
)


TestShiftActivity =  type(
    "TestShiftActivity",
    (
        plugin.HasWeatherPluginShiftAmountActivity,
        model.ShiftAmountActivity,  # the order is critical!
    ),
    {},
)

# %%
location_from_site = shapely.geometry.Point(-2.6939566, 48.536159)  # lon, lat
location_to_site = shapely.geometry.Point(-2.662230, 49.081062)  # lon, lat

data_from_site = {
    "env": my_env,
    "name": "Winlocatie",
    "geometry": location_from_site,
    "capacity": amount_MP_to_install,
    "level": amount_MP_to_install,
}


data_to_site = {
    "env": my_env,
    "name": "Dumplocatie",
    "geometry": location_to_site,
    "capacity": amount_MP_to_install,
    "level": 0,
}


from_site = Site(**data_from_site)
to_site = Site(**data_to_site)
# Out:
# init
# level: 20
# completed init
# init
# level: 0
# completed init

# %%
def compute_v_provider(v_empty, v_full):
    return lambda x: x * (v_full - v_empty) + v_empty

data_aeolus = {
    "env": my_env,
    "name": "Aeolus",
    "geometry": location_from_site,
    "capacity": capacity_aeolus,
    "compute_v": compute_v_provider(sailing_speed_empty, sailing_speed_full),
}

aeolus = TransportProcessingResource(**data_aeolus)
# Out:
# init
# level: 0.0
# completed init

# %%
metocean_df = pd.read_csv("../demo/metocean_format_pieter_maart_2020.csv")
metocean_df = metocean_df.set_index(pd.to_datetime(metocean_df["Time"], dayfirst=True))

metocean_df = metocean_df.sort_index()

metocean_df["DateTime"] = [datetime.datetime.strptime(dt, '%d-%m-%Y %H:%M') for dt in metocean_df["Time"]]

# %%
sailing_crit_full = core.WorkabilityCriterion(**{
    "event_name":"this",
    "condition":"Hs [m]",
    "maximum": sailing_full_limit,
    "window_length":datetime.timedelta(hours=1)
})

sailing_crit_empty = core.WorkabilityCriterion(**{
    "event_name":"this",
    "condition":"Hs [m]",
    "maximum": sailing_empty_limit,
    "window_length":datetime.timedelta(hours=1)
})

loading_crit = core.WorkabilityCriterion(**{
    "event_name":"this",
    "condition":"Hs [m]",
    "maximum":loading_limit,
    "window_length":datetime.timedelta(hours=1)
})

installing_crit = core.WorkabilityCriterion(**{
    "event_name":"this",
    "condition":"Hs [m]",
    "maximum": installing_limit,
    "window_length":datetime.timedelta(hours=1)
})

# %%
single_run = [
    TestMoveActivity(**{
        "env": my_env,
        "name": "Soil movement",
        "registry": registry,
        "mover": aeolus,
        "destination": from_site,
        "metocean_criteria":[sailing_crit_empty],
        "metocean_df": metocean_df,
        "timestep":1,
        "postpone_start": True,
    }),
    TestShiftActivity(**{
        "env": my_env,
        "name": "Transfer MP",
        "registry": registry,
        "processor": aeolus,
        "origin": from_site,
        "destination": aeolus,
        "amount": 4,    
        "duration": loading_duration*3600,
        "postpone_start": True,
        "metocean_criteria":[loading_crit],
        "metocean_df": metocean_df,
        "timestep":1,
    }),
    TestMoveActivity(**{
        "env": my_env,
        "name": "Soil movement",
        "registry": registry,
        "mover": aeolus,
        "destination": to_site,
        "metocean_criteria":[sailing_crit_full],
        "metocean_df": metocean_df,
        "postpone_start": True,
        "timestep":1,
    }),
    TestShiftActivity(**{
        "env": my_env,
        "name": "Transfer TP",
        "registry": registry,
        "processor": aeolus,
        "origin": aeolus,
        "destination": to_site,
        "amount": 4,
        "duration": installing_duration*3600,
        "postpone_start": True,
        "metocean_criteria":[installing_crit],
        "metocean_df": metocean_df,
        "timestep":1,
    })
]

activity = model.SequentialActivity(**{
    "env": my_env,
    "name": "Single run process",
    "ID": "6dbbbdf7-4589-11e9-bf3b-b469212bff60",
    "registry": registry,
    "sub_processes": single_run,
    "postpone_start": True,
})

expr = [{"type":"container", "concept": to_site, "state":"full"}] 

while_data = {
    "env": my_env,
    "name": "while",
    "registry": registry,
    "sub_process": activity,
    "condition_event": expr, # stop iteration once to_site is full
    "postpone_start": False,
}
while_activity = model.WhileActivity(**while_data)
# Out:
# check weather plugin
# True
# True
# True
# register weather plugin
# check weather plugin
# True
# True
# True
# register weather plugin
# check weather plugin
# True
# True
# True
# register weather plugin
# check weather plugin
# True
# True
# True
# register weather plugin
# while Activity keep_resources []
# get_full_event : default
# start get_available
# start event instance None

# %%
my_env.run()
# Out:
# <openclsim.model.SequentialActivity object at 0x000000A792D9B7C8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000000A792D9B808>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# put_callback - id_ default
# {}
# put_callback - id_ default
# {'default': {20: <Event() object at 0xa79316fb08>}}
# amount :20
# put_callback - id_ default
# {}
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2020-03-01T00:00:00.000000000' '2020-03-06T00:49:00.000000000']
#  ['2020-03-06T02:26:00.000000000' '2020-03-18T20:08:00.000000000']
#  ['2020-03-18T23:03:00.000000000' '2020-03-19T00:15:00.000000000']
#  ['2020-03-19T04:54:00.000000000' '2020-03-20T03:51:00.000000000']
#  ['2020-03-20T05:18:00.000000000' '2020-03-20T07:30:00.000000000']
#  ['2020-03-20T11:23:00.000000000' '2020-03-20T15:24:00.000000000']
#  ['2020-03-20T17:49:00.000000000' '2020-03-20T19:52:00.000000000']
#  ['2020-03-20T21:04:00.000000000' '2020-03-31T07:13:00.000000000']
#  ['2020-03-31T15:14:00.000000000' '2020-03-31T21:59:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1583017200.0
# after delay 1583017200.0
# Mover_move after move
# Activity end(Soil movement)
# <__main__.TestShiftActivity object at 0x000000A792DD4708>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.4930550a-af0e-11ea-9548-001a7dda7115': 20, 'destination.49320300-af0e-11ea-9837-001a7dda7115': 2.0}
# destination request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792dd44c8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792dd44c8>}
# site request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792dd44c8>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792d4ed88>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792dd44c8>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792d4ed88>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792dd44c8>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792d4ed88>}
# weatherPlugin start preprocess
# [['2020-03-01T00:00:00.000000000' '2020-03-05T15:51:00.000000000']
#  ['2020-03-05T19:26:00.000000000' '2020-03-05T23:21:00.000000000']
#  ['2020-03-06T05:25:00.000000000' '2020-03-15T13:48:00.000000000']
#  ['2020-03-15T19:10:00.000000000' '2020-03-18T18:06:00.000000000']
#  ['2020-03-19T10:06:00.000000000' '2020-03-19T13:27:00.000000000']
#  ['2020-03-19T16:31:00.000000000' '2020-03-19T23:55:00.000000000']
#  ['2020-03-20T21:47:00.000000000' '2020-03-22T18:49:00.000000000']
#  ['2020-03-22T23:17:00.000000000' '2020-03-25T21:13:00.000000000']
#  ['2020-03-26T03:25:00.000000000' '2020-03-26T03:40:00.000000000']
#  ['2020-03-26T05:16:00.000000000' '2020-03-27T01:35:00.000000000']
#  ['2020-03-27T04:03:00.000000000' '2020-03-28T13:50:00.000000000']
#  ['2020-03-28T16:12:00.000000000' '2020-03-29T22:56:00.000000000']
#  ['2020-03-30T01:09:00.000000000' '2020-03-30T18:07:00.000000000']
#  ['2020-03-31T18:48:00.000000000' '2020-03-31T21:59:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1583017200.0
# after delay 1583017200.0
# _shift_amount
# start _shift_amount
# amount 2.0
# processor start process
# install default at Aeolus
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 20, 'capacity': 20}]
# start get 2.0
# store_status {'id': 'default', 'level': 20, 'capacity': 20}
# end get 2.0
# get_callback - id_ <StorePut() object at 0xa792d73848>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 18.0, 'capacity': 20}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0.0, 'capacity': 2}]
# <FilterStoreGet() object at 0xa792dd4548>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 2.0, 'capacity': 2}]
# after put
# processor end process
# Processed 2.0 of default:
#   by:          Aeolus
#   origin        Winlocatie  contains: 18.0 of default
#   destination:  Aeolus contains: 2.0 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792dd44c8>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792d4ed88>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792d4ed88>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer MP)
# <__main__.TestMoveActivity object at 0x000000A792DDDF88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2020-03-01T18:27:00.000000000' '2020-03-01T22:02:00.000000000']
#  ['2020-03-02T00:13:00.000000000' '2020-03-02T10:29:00.000000000']
#  ['2020-03-02T22:18:00.000000000' '2020-03-03T13:57:00.000000000']
#  ['2020-03-03T15:11:00.000000000' '2020-03-03T17:31:00.000000000']
#  ['2020-03-03T21:01:00.000000000' '2020-03-04T01:23:00.000000000']
#  ['2020-03-04T04:07:00.000000000' '2020-03-04T06:20:00.000000000']
#  ['2020-03-04T09:11:00.000000000' '2020-03-04T11:39:00.000000000']
#  ['2020-03-05T00:18:00.000000000' '2020-03-05T10:04:00.000000000']
#  ['2020-03-24T08:30:00.000000000' '2020-03-24T20:59:00.000000000']
#  ['2020-03-24T22:03:00.000000000' '2020-03-25T00:50:00.000000000']
#  ['2020-03-25T02:10:00.000000000' '2020-03-25T03:37:00.000000000']
#  ['2020-03-25T05:58:00.000000000' '2020-03-25T07:34:00.000000000']
#  ['2020-03-25T09:09:00.000000000' '2020-03-25T16:23:00.000000000']
#  ['2020-03-25T18:36:00.000000000' '2020-03-25T18:47:00.000000000']
#  ['2020-03-26T08:51:00.000000000' '2020-03-26T10:45:00.000000000']
#  ['2020-03-26T12:53:00.000000000' '2020-03-26T22:26:00.000000000']
#  ['2020-03-27T14:04:00.000000000' '2020-03-28T04:22:00.000000000']
#  ['2020-03-28T21:55:00.000000000' '2020-03-29T22:15:00.000000000']
#  ['2020-03-30T04:12:00.000000000' '2020-03-30T11:26:00.000000000']
#  ['2020-03-30T15:55:00.000000000' '2020-03-30T16:47:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1583113940.6447587
# after delay 1583113940.6447587
# _shift_amount
# start _shift_amount
# amount 2.0
# processor start process
# install default at Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 2.0, 'capacity': 2}]
# start get 2.0
# store_status {'id': 'default', 'level': 2.0, 'capacity': 2}
# end get 2.0
# get_callback - id_ <StorePut() object at 0xa792da8ac8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0.0, 'capacity': 2}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0, 'capacity': 20}]
# <FilterStoreGet() object at 0xa792da8ac8>
# put_callback - id_ default
# {'default': {20: <Event() object at 0xa79316fb08>}}
# amount :20
# destination store after put: [{'id': 'default', 'level': 2.0, 'capacity': 20}]
# after put
# processor end process
# Processed 2.0 of default:
#   by:          Aeolus
#   origin        Aeolus  contains: 0.0 of default
#   destination:  Dumplocatie contains: 2.0 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa791891808>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa791576808>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa791576808>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: False False round 0
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000000A792D9B7C8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000000A792D9B808>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2020-03-01T00:00:00.000000000' '2020-03-06T00:49:00.000000000']
#  ['2020-03-06T02:26:00.000000000' '2020-03-18T20:08:00.000000000']
#  ['2020-03-18T23:03:00.000000000' '2020-03-19T00:15:00.000000000']
#  ['2020-03-19T04:54:00.000000000' '2020-03-20T03:51:00.000000000']
#  ['2020-03-20T05:18:00.000000000' '2020-03-20T07:30:00.000000000']
#  ['2020-03-20T11:23:00.000000000' '2020-03-20T15:24:00.000000000']
#  ['2020-03-20T17:49:00.000000000' '2020-03-20T19:52:00.000000000']
#  ['2020-03-20T21:04:00.000000000' '2020-03-31T07:13:00.000000000']
#  ['2020-03-31T15:14:00.000000000' '2020-03-31T21:59:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1583142740.6447587
# after delay 1583142740.6447587
# Mover_move after move
# Activity end(Soil movement)
# <__main__.TestShiftActivity object at 0x000000A792DD4708>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.4930550a-af0e-11ea-9548-001a7dda7115': 18.0, 'destination.49320300-af0e-11ea-9837-001a7dda7115': 2.0}
# destination request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d96f48>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d96f48>}
# site request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d96f48>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792db0688>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d96f48>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792db0688>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d96f48>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa
00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1583214875.05269
# after delay 1583214875.05269
# _shift_amount
# start _shift_amount
# amount 2.0
# processor start process
# install default at Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 2.0, 'capacity': 2}]
# start get 2.0
# store_status {'id': 'default', 'level': 2.0, 'capacity': 2}
# end get 2.0
# get_callback - id_ <StorePut() object at 0xa792db0408>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0.0, 'capacity': 2}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 2.0, 'capacity': 20}]
# <FilterStoreGet() object at 0xa792db0408>
# put_callback - id_ default
# {'default': {20: <Event() object at 0xa79316fb08>}}
# amount :20
# destination store after put: [{'id': 'default', 'level': 4.0, 'capacity': 20}]
# after put
# processor end process
# Processed 2.0 of default:
#   by:          Aeolus
#   origin        Aeolus  contains: 0.0 of default
#   destination:  Dumplocatie contains: 4.0 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa792d73fc8>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792db0148>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792db0148>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: False False round 1
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000000A792D9B7C8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000000A792D9B808>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2020-03-01T00:00:00.000000000' '2020-03-06T00:49:00.000000000']
#  ['2020-03-06T02:26:00.000000000' '2020-03-18T20:08:00.000000000']
#  ['2020-03-18T23:03:00.000000000' '2020-03-19T00:15:00.000000000']
#  ['2020-03-19T04:54:00.000000000' '2020-03-20T03:51:00.000000000']
#  ['2020-03-20T05:18:00.000000000' '2020-03-20T07:30:00.000000000']
#  ['2020-03-20T11:23:00.000000000' '2020-03-20T15:24:00.000000000']
#  ['2020-03-20T17:49:00.000000000' '2020-03-20T19:52:00.000000000']
#  ['2020-03-20T21:04:00.000000000' '2020-03-31T07:13:00.000000000']
#  ['2020-03-31T15:14:00.000000000' '2020-03-31T21:59:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1583243675.05269
# after delay 1583243675.05269
# Mover_move after move
# Activity end(Soil movement)
# <__main__.TestShiftActivity object at 0x000000A792DD4708>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.4930550a-af0e-11ea-9548-001a7dda7115': 16.0, 'destination.49320300-af0e-11ea-9837-001a7dda7115': 2.0}
# destination request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d48>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d48>}
# site request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d48>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792db0d48>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d48>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792db0d48>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d48>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792db0d48>}
# weatherPlugin start preprocess
# [['2020-03-01T00:00:00.000000000' '2020-03-05T15:51:00.000000000']
#  ['2020-03-05T19:26:00.000000000' '2020-03-05T23:21:00.000000000']
#  ['2020-03-06T05:25:00.000000000' '2020-03-15T13:48:00.000000000']
#  ['2020-03-15T19:10:00.000000000' '2020-03-18T18:06:00.000000000']
#  ['2020-03-19T10:06:00.000000000' '2020-03-19T13:27:00.000000000']
#  ['2020-03-19T16:31:00.000000000' '2020-03-19T23:55:00.000000000']
#  ['2020-03-20T21:47:00.000000000' '2020-03-22T18:49:00.000000000']
#  ['2020-03-22T23:17:00.000000000' '2020-03-25T21:13:00.000000000']
#  ['2020-03-26T03:25:00.000000000' '2020-03-26T03:40:00.000000000']
#  ['2020-03-26T05:16:00.000000000' '2020-03-27T01:35:00.000000000']
#  ['2020-03-27T04:03:00.000000000' '2020-03-28T13:50:00.000000000']
#  ['2020-03-28T16:12:00.000000000' '2020-03-29T22:56:00.000000000']
#  ['2020-03-30T01:09:00.000000000' '2020-03-30T18:07:00.000000000']
#  ['2020-03-31T18:48:00.000000000' '2020-03-31T21:59:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1583263888.8158627
# after delay 1583263888.8158627
# _shift_amount
# start _shift_amount
# amount 2.0
# processor start process
# install default at Aeolus
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 16.0, 'capacity': 20}]
# start get 2.0
# store_status {'id': 'default', 'level': 16.0, 'capacity': 20}
# end get 2.0
# get_callback - id_ <StorePut() object at 0xa792db0ec8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 14.0, 'capacity': 20}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0.0, 'capacity': 2}]
# <FilterStoreGet() object at 0xa792db0ec8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 2.0, 'capacity': 2}]
# after put
# processor end process
# Processed 2.0 of default:
#   by:          Aeolus
#   origin        Winlocatie  contains: 14.0 of default
#   destination:  Aeolus contains: 2.0 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d48>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792db0d48>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792db0d48>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer MP)
# <__main__.TestMoveActivity object at 0x000000A792DDDF88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2020-03-01T18:27:00.000000000' '2020-03-01T22:02:00.000000000']
#  ['2020-03-02T00:13:00.000000000' '2020-03-02T10:29:00.000000000']
#  ['2020-03-02T22:18:00.000000000' '2020-03-03T13:57:00.000000000']
#  ['2020-03-03T15:11:00.000000000' '2020-03-03T17:31:00.000000000']
#  ['2020-03-03T21:01:00.000000000' '2020-03-04T01:23:00.000000000']
#  ['2020-03-04T04:07:00.000000000' '2020-03-04T06:20:00.000000000']
#  ['2020-03-04T09:11:00.000000000' '2020-03-04T11:39:00.000000000']
#  ['2020-03-05T00:18:00.000000000' '2020-03-05T10:04:00.000000000']
#  ['2020-03-07T00:36:00.000000000' '2020-03-08T05:52:00.000000000']
#  ['2020-03-08T22:35:00.000000000' '2020-03-09T17:52:00.000000000']
#  ['2020-03-09T20:54:00.000000000' '2020-03-10T05:36:00.000000000']
#  ['2020-03-10T07:19:00.000000000' '2020-03-10T09:25:00.000000000']
#  ['2020-03-11T06:14:00.000000000' '2020-03-11T12:37:00.000000000']
#  ['2020-03-11T22:59:00.000000000' '2020-03-12T00:16:00.000000000']
#  ['2020-03-12T02:49:00.000000000' '2020-03-12T04:31:00.000000000']
#  ['2020-03-12T09:26:00.000000000' '2020-03-12T20:56:00.000000000']
#  ['2020-03-15T06:10:00.000000000' '2020-03-15T06:26:00.000000000']
#  ['2020-03-16T01:42:00.000000000' '2020-03-16T11:34:00.000000000']
#  ['2020-03-16T19:35:00.000000000' '2020-03-16T19:48:00.000000000']
#  ['2020-03-21T11:00:00.000000000' '2020-03-21T20:37:00.000000000']
#  ['2020-03-23T04:35:00.000000000' '2020-03-23T20:13:00.000000000']
#  ['2020-03-24T09:52:00.000000000' '2020-03-24T13:18:00.000000000']
#  ['2020-03-24T18:55:00.000000000' '2020-03-24T20:10:00.000000000']
#  ['2020-03-25T11:13:00.000000000' '2020-03-25T12:16:00.000000000']
#  ['2020-03-26T18:15:00.000000000' '2020-03-26T20:26:00.000000000']
#  ['2020-03-29T01:11:00.000000000' '2020-03-29T14:38:00.000000000']
#  ['2020-03-29T16:11:00.000000000' '2020-03-29T17:45:00.000000000']]
# [5731.184137]
# we have to wait for 5731.184137
# delay processing 5731.184137
# before delay 1583285488.8158627
# after delay 1583291219.9999998
# Mover_move after move
# Activity end(Soil movement)
# <__main__.TestShiftActivity object at 0x000000A792DDD888>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.49320300-af0e-11ea-9837-001a7dda7115': 2.0, 'destination.49307c22-af0e-11ea-898e-001a7dda7115': 16.0}
# destination request : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa792ddd708>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa792ddd708>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792da9e48>}
# site request : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa792ddd708>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792da9e48>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa792ddd708>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792da9e48>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa792ddd708>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792da9e48>}
# weatherPlugin start preprocess
# [['2020-03-01T02:18:00.000000000' '2020-03-05T13:06:00.000000000']
#  ['2020-03-06T08:16:00.000000000' '2020-03-10T15:50:00.000000000']
#  ['2020-03-10T22:35:00.000000000' '2020-03-11T00:11:00.000000000']
#  ['2020-03-11T03:13:00.000000000' '2020-03-13T10:55:00.000000000']
#  ['2020-03-13T12:11:00.000000000' '2020-03-13T12:28:00.000000000']
#  ['2020-03-13T17:53:00.000000000' '2020-03-13T21:53:00.000000000']
#  ['2020-03-13T23:08:00.000000000' '2020-03-13T23:27:00.000000000']
#  ['2020-03-14T18:06:00.000000000' '2020-03-15T07:43:00.000000000']
#  ['2020-03-15T23:35:00.000000000' '2020-03-17T02:35:00.000000000']
#  ['2020-03-17T04:16:00.000000000' '2020-03-17T04:45:00.000000000']
#  ['2020-03-17T19:22:00.000000000' '2020-03-18T06:15:00.000000000']
#  ['2020-03-18T08:34:00.000000000' '2020-03-18T09:25:00.000000000']
#  ['2020-03-21T01:35:00.000000000' '2020-03-22T10:27:00.000000000']
#  ['2020-03-23T01:56:00.000000000' '2020-03-24T03:52:00.000000000']
#  ['2020-03-24T08:30:00.000000000' '2020-03-24T20:59:00.000000000']
#  ['2020-03-24T22:03:00.000000000' '2020-03-25T00:50:00.000000000']
#  ['2020-03-25T02:10:00.000000000' '2020-03-25T03:37:00.000000000']
#  ['2020-03-25T05:58:00.000000000' '2020-03-25T07:34:00.000000000']
#  ['2020-03-25T09:09:00.000000000' '2020-03-25T16:23:00.000000000']
#  ['2020-03-25T18:36:00.000000000' '2020-03-25T18:47:00.000000000']
#  ['2020-03-26T08:51:00.000000000' '2020-03-26T10:45:00.000000000']
#  ['2020-03-26T12:53:00.000000000' '2020-03-26T22:26:00.000000000']
#  ['2020-03-27T14:04:00.000000000' '2020-03-28T04:22:00.000000000']
#  ['2020-03-28T21:55:00.000000000' '2020-03-29T22:15:00.000000000']
#  ['2020-03-30T04:12:00.000000000' '2020-03-30T11:26:00.000000000']
#  ['2020-03-30T15:55:00.000000000' '2020-03-30T16:47:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1583321540.6447585
# after delay 1583321540.6447585
# _shift_amount
# start _shift_amount
# amount 2.0
# processor start process
# install default at Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 2.0, 'capacity': 2}]
# start get 2.0
# store_status {'id': 'default', 'level': 2.0, 'capacity': 2}
# end get 2.0
# get_callback - id_ <StorePut() object at 0xa78b35ca88>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0.0, 'capacity': 2}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 4.0, 'capacity': 20}]
# <FilterStoreGet() object at 0xa78b35ca88>
# put_callback - id_ default
# {'default': {20: <Event() object at 0xa79316fb08>}}
# amount :20
# destination store after put: [{'id': 'default', 'level': 6.0, 'capacity': 20}]
# after put
# processor end process
# Processed 2.0 of default:
#   by:          Aeolus
#   origin        Aeolus  contains: 0.0 of default
#   destination:  Dumplocatie contains: 6.0 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa792ddd708>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792da9e48>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792da9e48>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: False False round 2
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000000A792D9B7C8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000000A792D9B808>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2020-03-01T00:00:00.000000000' '2020-03-06T00:49:00.000000000']
#  ['2020-03-06T02:26:00.000000000' '2020-03-18T20:08:00.000000000']
#  ['2020-03-18T23:03:00.000000000' '2020-03-19T00:15:00.000000000']
#  ['2020-03-19T04:54:00.000000000' '2020-03-20T03:51:00.000000000']
#  ['2020-03-20T05:18:00.000000000' '2020-03-20T07:30:00.000000000']
#  ['2020-03-20T11:23:00.000000000' '2020-03-20T15:24:00.000000000']
#  ['2020-03-20T17:49:00.000000000' '2020-03-20T19:52:00.000000000']
#  ['2020-03-20T21:04:00.000000000' '2020-03-31T07:13:00.000000000']
#  ['2020-03-31T15:14:00.000000000' '2020-03-31T21:59:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1583350340.6447585
# after delay 1583350340.6447585
# Mover_move after move
# Activity end(Soil movement)
# <__main__.TestShiftActivity object at 0x000000A792DD4708>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.4930550a-af0e-11ea-9548-001a7dda7115': 14.0, 'destination.49320300-af0e-11ea-9837-001a7dda7115': 2.0}
# destination request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73448>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73448>}
# site request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73448>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792d5e408>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73448>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792d5e408>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73448>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792d5e408>}
# weatherPlugin start preprocess
# [['2020-03-01T00:00:00.000000000' '2020-03-05T15:51:00.000000000']
#  ['2020-03-05T19:26:00.000000000' '2020-03-05T23:21:00.000000000']
#  ['2020-03-06T05:25:00.000000000' '2020-03-15T13:48:00.000000000']
#  ['2020-03-15T19:10:00.000000000' '2020-03-18T18:06:00.000000000']
#  ['2020-03-19T10:06:00.000000000' '2020-03-19T13:27:00.000000000']
#  ['2020-03-19T16:31:00.000000000' '2020-03-19T23:55:00.000000000']
#  ['2020-03-20T21:47:00.000000000' '2020-03-22T18:49:00.000000000']
#  ['2020-03-22T23:17:00.000000000' '2020-03-25T21:13:00.000000000']
#  ['2020-03-26T03:25:00.000000000' '2020-03-26T03:40:00.000000000']
#  ['2020-03-26T05:16:00.000000000' '2020-03-27T01:35:00.000000000']
#  ['2020-03-27T04:03:00.000000000' '2020-03-28T13:50:00.000000000']
#  ['2020-03-28T16:12:00.000000000' '2020-03-29T22:56:00.000000000']
#  ['2020-03-30T01:09:00.000000000' '2020-03-30T18:07:00.000000000']
#  ['2020-03-31T18:48:00.000000000' '2020-03-31T21:59:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1583370554.407931
# after delay 1583370554.407931
# _shift_amount
# start _shift_amount
# amount 2.0
# processor start process
# install default at Aeolus
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 14.0, 'capacity': 20}]
# start get 2.0
# store_status {'id': 'default', 'level': 14.0, 'capacity': 20}
# end get 2.0
# get_callback - id_ <StorePut() object at 0xa792d5e188>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 12.0, 'capacity': 20}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0.0, 'capacity': 2}]
# <FilterStoreGet() object at 0xa792d5e188>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 2.0, 'capacity': 2}]
# after put
# processor end process
# Processed 2.0 of default:
#   by:          Aeolus
#   origin        Winlocatie  contains: 12.0 of default
#   destination:  Aeolus contains: 2.0 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73448>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792d5e408>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa792d5e408>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer MP)
# <__main__.TestMoveActivity object at 0x000000A792DDDF88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['
#  ['2020-03-15T23:35:00.000000000' '2020-03-17T02:35:00.000000000']
#  ['2020-03-17T04:16:00.000000000' '2020-03-17T04:45:00.000000000']
#  ['2020-03-17T19:22:00.000000000' '2020-03-18T06:15:00.000000000']
#  ['2020-03-18T08:34:00.000000000' '2020-03-18T09:25:00.000000000']
#  ['2020-03-21T01:35:00.000000000' '2020-03-22T10:27:00.000000000']
#  ['2020-03-23T01:56:00.000000000' '2020-03-24T03:52:00.000000000']
#  ['2020-03-24T08:30:00.000000000' '2020-03-24T20:59:00.000000000']
#  ['2020-03-24T22:03:00.000000000' '2020-03-25T00:50:00.000000000']
#  ['2020-03-25T02:10:00.000000000' '2020-03-25T03:37:00.000000000']
#  ['2020-03-25T05:58:00.000000000' '2020-03-25T07:34:00.000000000']
#  ['2020-03-25T09:09:00.000000000' '2020-03-25T16:23:00.000000000']
#  ['2020-03-25T18:36:00.000000000' '2020-03-25T18:47:00.000000000']
#  ['2020-03-26T08:51:00.000000000' '2020-03-26T10:45:00.000000000']
#  ['2020-03-26T12:53:00.000000000' '2020-03-26T22:26:00.000000000']
#  ['2020-03-27T14:04:00.000000000' '2020-03-28T04:22:00.000000000']
#  ['2020-03-28T21:55:00.000000000' '2020-03-29T22:15:00.000000000']
#  ['2020-03-30T04:12:00.000000000' '2020-03-30T11:26:00.000000000']
#  ['2020-03-30T15:55:00.000000000' '2020-03-30T16:47:00.000000000']]
# [56484.94731]
# we have to wait for 56484.94731
# delay processing 56484.94731
# before delay 1583422475.0526898
# after delay 1583478959.9999998
# _shift_amount
# start _shift_amount
# amount 2.0
# processor start process
# install default at Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 2.0, 'capacity': 2}]
# start get 2.0
# store_status {'id': 'default', 'level': 2.0, 'capacity': 2}
# end get 2.0
# get_callback - id_ <StorePut() object at 0xa792d962c8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0.0, 'capacity': 2}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 6.0, 'capacity': 20}]
# <FilterStoreGet() object at 0xa792d962c8>
# put_callback - id_ default
# {'default': {20: <Event() object at 0xa79316fb08>}}
# amount :20
# destination store after put: [{'id': 'default', 'level': 8.0, 'capacity': 20}]
# after put
# processor end process
# Processed 2.0 of default:
#   by:          Aeolus
#   origin        Aeolus  contains: 0.0 of default
#   destination:  Dumplocatie contains: 8.0 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa791576d48>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d4ec88>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d4ec88>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: False False round 3
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000000A792D9B7C8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000000A792D9B808>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2020-03-01T00:00:00.000000000' '2020-03-06T00:49:00.000000000']
#  ['2020-03-06T02:26:00.000000000' '2020-03-18T20:08:00.000000000']
#  ['2020-03-18T23:03:00.000000000' '2020-03-19T00:15:00.000000000']
#  ['2020-03-19T04:54:00.000000000' '2020-03-20T03:51:00.000000000']
#  ['2020-03-20T05:18:00.000000000' '2020-03-20T07:30:00.000000000']
#  ['2020-03-20T11:23:00.000000000' '2020-03-20T15:24:00.000000000']
#  ['2020-03-20T17:49:00.000000000' '2020-03-20T19:52:00.000000000']
#  ['2020-03-20T21:04:00.000000000' '2020-03-31T07:13:00.000000000']
#  ['2020-03-31T15:14:00.000000000' '2020-03-31T21:59:00.000000000']]
# [0.0]
# ...
# site request : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa79316f288>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d9b3c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa79316f288>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d9b3c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa79316f288>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d9b3c8>}
# weatherPlugin start preprocess
# [['2020-03-01T02:18:00.000000000' '2020-03-05T13:06:00.000000000']
#  ['2020-03-06T08:16:00.000000000' '2020-03-10T15:50:00.000000000']
#  ['2020-03-10T22:35:00.000000000' '2020-03-11T00:11:00.000000000']
#  ['2020-03-11T03:13:00.000000000' '2020-03-13T10:55:00.000000000']
#  ['2020-03-13T12:11:00.000000000' '2020-03-13T12:28:00.000000000']
#  ['2020-03-13T17:53:00.000000000' '2020-03-13T21:53:00.000000000']
#  ['2020-03-13T23:08:00.000000000' '2020-03-13T23:27:00.000000000']
#  ['2020-03-14T18:06:00.000000000' '2020-03-15T07:43:00.000000000']
#  ['2020-03-15T23:35:00.000000000' '2020-03-17T02:35:00.000000000']
#  ['2020-03-17T04:16:00.000000000' '2020-03-17T04:45:00.000000000']
#  ['2020-03-17T19:22:00.000000000' '2020-03-18T06:15:00.000000000']
#  ['2020-03-18T08:34:00.000000000' '2020-03-18T09:25:00.000000000']
#  ['2020-03-21T01:35:00.000000000' '2020-03-22T10:27:00.000000000']
#  ['2020-03-23T01:56:00.000000000' '2020-03-24T03:52:00.000000000']
#  ['2020-03-24T08:30:00.000000000' '2020-03-24T20:59:00.000000000']
#  ['2020-03-24T22:03:00.000000000' '2020-03-25T00:50:00.000000000']
#  ['2020-03-25T02:10:00.000000000' '2020-03-25T03:37:00.000000000']
#  ['2020-03-25T05:58:00.000000000' '2020-03-25T07:34:00.000000000']
#  ['2020-03-25T09:09:00.000000000' '2020-03-25T16:23:00.000000000']
#  ['2020-03-25T18:36:00.000000000' '2020-03-25T18:47:00.000000000']
#  ['2020-03-26T08:51:00.000000000' '2020-03-26T10:45:00.000000000']
#  ['2020-03-26T12:53:00.000000000' '2020-03-26T22:26:00.000000000']
#  ['2020-03-27T14:04:00.000000000' '2020-03-28T04:22:00.000000000']
#  ['2020-03-28T21:55:00.000000000' '2020-03-29T22:15:00.000000000']
#  ['2020-03-30T04:12:00.000000000' '2020-03-30T11:26:00.000000000']
#  ['2020-03-30T15:55:00.000000000' '2020-03-30T16:47:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1584036423.8685524
# after delay 1584036423.8685524
# _shift_amount
# start _shift_amount
# amount 2.0
# processor start process
# install default at Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 2.0, 'capacity': 2}]
# start get 2.0
# store_status {'id': 'default', 'level': 2.0, 'capacity': 2}
# end get 2.0
# get_callback - id_ <StorePut() object at 0xa7931406c8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0.0, 'capacity': 2}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 16.0, 'capacity': 20}]
# <FilterStoreGet() object at 0xa7931406c8>
# put_callback - id_ default
# {'default': {20: <Event() object at 0xa79316fb08>}}
# amount :20
# destination store after put: [{'id': 'default', 'level': 18.0, 'capacity': 20}]
# after put
# processor end process
# Processed 2.0 of default:
#   by:          Aeolus
#   origin        Aeolus  contains: 0.0 of default
#   destination:  Dumplocatie contains: 18.0 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa79316f288>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d9b3c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d9b3c8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: False False round 8
# while loop requested_resources {}
# while loop keep_resources []
# <openclsim.model.SequentialActivity object at 0x000000A792D9B7C8>
# conditional
# start event instance None
# <__main__.TestMoveActivity object at 0x000000A792D9B808>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2020-03-01T00:00:00.000000000' '2020-03-06T00:49:00.000000000']
#  ['2020-03-06T02:26:00.000000000' '2020-03-18T20:08:00.000000000']
#  ['2020-03-18T23:03:00.000000000' '2020-03-19T00:15:00.000000000']
#  ['2020-03-19T04:54:00.000000000' '2020-03-20T03:51:00.000000000']
#  ['2020-03-20T05:18:00.000000000' '2020-03-20T07:30:00.000000000']
#  ['2020-03-20T11:23:00.000000000' '2020-03-20T15:24:00.000000000']
#  ['2020-03-20T17:49:00.000000000' '2020-03-20T19:52:00.000000000']
#  ['2020-03-20T21:04:00.000000000' '2020-03-31T07:13:00.000000000']
#  ['2020-03-31T15:14:00.000000000' '2020-03-31T21:59:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1584065223.8685524
# after delay 1584065223.8685524
# Mover_move after move
# Activity end(Soil movement)
# <__main__.TestShiftActivity object at 0x000000A792DD4708>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.4930550a-af0e-11ea-9548-001a7dda7115': 2.0, 'destination.49320300-af0e-11ea-9837-001a7dda7115': 2.0}
# destination request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d08>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d08>}
# site request : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d08>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa7931408c8>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d08>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa7931408c8>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d08>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa7931408c8>}
# weatherPlugin start preprocess
# [['2020-03-01T00:00:00.000000000' '2020-03-05T15:51:00.000000000']
#  ['2020-03-05T19:26:00.000000000' '2020-03-05T23:21:00.000000000']
#  ['2020-03-06T05:25:00.000000000' '2020-03-15T13:48:00.000000000']
#  ['2020-03-15T19:10:00.000000000' '2020-03-18T18:06:00.000000000']
#  ['2020-03-19T10:06:00.000000000' '2020-03-19T13:27:00.000000000']
#  ['2020-03-19T16:31:00.000000000' '2020-03-19T23:55:00.000000000']
#  ['2020-03-20T21:47:00.000000000' '2020-03-22T18:49:00.000000000']
#  ['2020-03-22T23:17:00.000000000' '2020-03-25T21:13:00.000000000']
#  ['2020-03-26T03:25:00.000000000' '2020-03-26T03:40:00.000000000']
#  ['2020-03-26T05:16:00.000000000' '2020-03-27T01:35:00.000000000']
#  ['2020-03-27T04:03:00.000000000' '2020-03-28T13:50:00.000000000']
#  ['2020-03-28T16:12:00.000000000' '2020-03-29T22:56:00.000000000']
#  ['2020-03-30T01:09:00.000000000' '2020-03-30T18:07:00.000000000']
#  ['2020-03-31T18:48:00.000000000' '2020-03-31T21:59:00.000000000']]
# [0.0]
# we have to wait for 0.0
# delay processing 0.0
# before delay 1584085437.631725
# after delay 1584085437.631725
# _shift_amount
# start _shift_amount
# amount 2.0
# processor start process
# install default at Aeolus
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 2.0, 'capacity': 20}]
# start get 2.0
# store_status {'id': 'default', 'level': 2.0, 'capacity': 20}
# end get 2.0
# get_callback - id_ <StorePut() object at 0xa7931404c8>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0.0, 'capacity': 20}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 0.0, 'capacity': 2}]
# <FilterStoreGet() object at 0xa7931404c8>
# put_callback - id_ default
# {}
# destination store after put: [{'id': 'default', 'level': 2.0, 'capacity': 2}]
# after put
# processor end process
# Processed 2.0 of default:
#   by:          Aeolus
#   origin        Winlocatie  contains: 0.0 of default
#   destination:  Aeolus contains: 2.0 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa792d73d08>, <simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa7931408c8>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000000A792D5EA48>: <Request() object at 0xa7931408c8>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer MP)
# <__main__.TestMoveActivity object at 0x000000A792DDDF88>
# keep_resources []
# start event instance None
# Mover_move before mover resource request
# Mover_move after mover resource request
# weatherPlugin start preprocess
# [['2020-03-01T18:27:00.000000000' '2020-03-01T22:02:00.000000000']
#  ['2020-03-02T00:13:00.000000000' '2020-03-02T10:29:00.000000000']
#  ['2020-03-02T22:18:00.000000000' '2020-03-03T13:57:00.000000000']
#  ['2020-03-03T15:11:00.000000000' '2020-03-03T17:31:00.000000000']
#  ['2020-03-03T21:01:00.000000000' '2020-03-04T01:23:00.000000000']
#  ['2020-03-04T04:07:00.000000000' '2020-03-04T06:20:00.000000000']
#  ['2020-03-04T09:11:00.000000000' '2020-03-04T11:39:00.000000000']
#  ['2020-03-05T00:18:00.000000000' '2020-03-05T10:04:00.000000000']
#  ['2020-03-07T00:36:00.000000000' '2020-03-08T05:52:00.000000000']
#  ['2020-03-08T22:35:00.000000000' '2020-03-09T17:52:00.000000000']
#  ['2020-03-09T20:54:00.000000000' '2020-03-10T05:36:00.000000000']
#  ['2020-03-10T07:19:00.000000000' '2020-03-10T09:25:00.000000000']
#  ['2020-03-11T06:14:00.000000000' '2020-03-11T12:37:00.000000000']
#  ['2020-03-11T22:59:00.000000000' '2020-03-12T00:16:00.000000000']
#  ['2020-03-12T02:49:00.000000000' '2020-03-12T04:31:00.000000000']
#  ['2020-03-12T09:26:00.000000000' '2020-03-12T20:56:00.000000000']
#  ['2020-03-15T06:10:00.000000000' '2020-03-15T06:26:00.000000000']
#  ['2020-03-16T01:42:00.000000000' '2020-03-16T11:34:00.000000000']
#  ['2020-03-16T19:35:00.000000000' '2020-03-16T19:48:00.000000000']
#  ['2020-03-21T11:00:00.000000000' '2020-03-21T20:37:00.000000000']
#  ['2020-03-23T04:35:00.000000000' '2020-03-23T20:13:00.000000000']
#  ['2020-03-24T09:52:00.000000000' '2020-03-24T13:18:00.000000000']
#  ['2020-03-24T18:55:00.000000000' '2020-03-24T20:10:00.000000000']
#  ['2020-03-25T11:13:00.000000000' '2020-03-25T12:16:00.000000000']
#  ['2020-03-26T18:15:00.000000000' '2020-03-26T20:26:00.000000000']
#  ['2020-03-29T01:11:00.000000000' '2020-03-29T14:38:00.000000000']
#  ['2020-03-29T16:11:00.000000000' '2020-03-29T17:45:00.000000000']]
# [141962.368275]
# we have to wait for 141962.368275
# delay processing 141962.368275
# before delay 1584107037.631725
# after delay 1584249000.0
# Mover_move after move
# Activity end(Soil movement)
# <__main__.TestShiftActivity object at 0x000000A792DDD888>
# keep_resources []
# SHift amount Activity keep_resources []
# start event instance None
# start : {}
# {'origin.49320300-af0e-11ea-9837-001a7dda7115': 2.0, 'destination.49307c22-af0e-11ea-898e-001a7dda7115': 2.0}
# destination request : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa793140bc8>}
# shift amount process keep_resources []
# start get_available
# processor request : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa793140bc8>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa793140b08>}
# site request : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa793140bc8>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa793140b08>}
# end requestIfAvailable : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa793140bc8>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa793140b08>}
# after req resource if available : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa793140bc8>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa793140b08>}
# weatherPlugin start preprocess
# [['2020-03-01T02:18:00.000000000' '2020-03-05T13:06:00.000000000']
#  ['2020-03-06T08:16:00.000000000' '2020-03-10T15:50:00.000000000']
#  ['2020-03-10T22:35:00.000000000' '2020-03-11T00:11:00.000000000']
#  ['2020-03-11T03:13:00.000000000' '2020-03-13T10:55:00.000000000']
#  ['2020-03-13T12:11:00.000000000' '2020-03-13T12:28:00.000000000']
#  ['2020-03-13T17:53:00.000000000' '2020-03-13T21:53:00.000000000']
#  ['2020-03-13T23:08:00.000000000' '2020-03-13T23:27:00.000000000']
#  ['2020-03-14T18:06:00.000000000' '2020-03-15T07:43:00.000000000']
#  ['2020-03-15T23:35:00.000000000' '2020-03-17T02:35:00.000000000']
#  ['2020-03-17T04:16:00.000000000' '2020-03-17T04:45:00.000000000']
#  ['2020-03-17T19:22:00.000000000' '2020-03-18T06:15:00.000000000']
#  ['2020-03-18T08:34:00.000000000' '2020-03-18T09:25:00.000000000']
#  ['2020-03-21T01:35:00.000000000' '2020-03-22T10:27:00.000000000']
#  ['2020-03-23T01:56:00.000000000' '2020-03-24T03:52:00.000000000']
#  ['2020-03-24T08:30:00.000000000' '2020-03-24T20:59:00.000000000']
#  ['2020-03-24T22:03:00.000000000' '2020-03-25T00:50:00.000000000']
#  ['2020-03-25T02:10:00.000000000' '2020-03-25T03:37:00.000000000']
#  ['2020-03-25T05:58:00.000000000' '2020-03-25T07:34:00.000000000']
#  ['2020-03-25T09:09:00.000000000' '2020-03-25T16:23:00.000000000']
#  ['2020-03-25T18:36:00.000000000' '2020-03-25T18:47:00.000000000']
#  ['2020-03-26T08:51:00.000000000' '2020-03-26T10:45:00.000000000']
#  ['2020-03-26T12:53:00.000000000' '2020-03-26T22:26:00.000000000']
#  ['2020-03-27T14:04:00.000000000' '2020-03-28T04:22:00.000000000']
#  ['2020-03-28T21:55:00.000000000' '2020-03-29T22:15:00.000000000']
#  ['2020-03-30T04:12:00.000000000' '2020-03-30T11:26:00.000000000']
#  ['2020-03-30T15:55:00.000000000' '2020-03-30T16:47:00.000000000']]
# [32379.355241]
# we have to wait for 32379.355241
# delay processing 32379.355241
# before delay 1584279320.6447587
# after delay 1584311699.9999998
# _shift_amount
# start _shift_amount
# amount 2.0
# processor start process
# install default at Dumplocatie
# processor process without rate
# origin store before get: [{'id': 'default', 'level': 2.0, 'capacity': 2}]
# start get 2.0
# store_status {'id': 'default', 'level': 2.0, 'capacity': 2}
# end get 2.0
# get_callback - id_ <StorePut() object at 0xa792db0e08>
# start get_callback
# {}
# origin store after get: [{'id': 'default', 'level': 0.0, 'capacity': 2}]
# after get
# after check_down time
# destination store before put: [{'id': 'default', 'level': 18.0, 'capacity': 20}]
# <FilterStoreGet() object at 0xa792db0e08>
# put_callback - id_ default
# {'default': {20: <Event() object at 0xa79316fb08>}}
# amount :20
# destination store after put: [{'id': 'default', 'level': 20.0, 'capacity': 20}]
# after put
# processor end process
# Processed 2.0 of default:
#   by:          Aeolus
#   origin        Aeolus  contains: 0.0 of default
#   destination:  Dumplocatie contains: 20.0 of default
# after shift amount : {<simpy.resources.resource.Resource object at 0x000000A792D5EEC8>: <Request() object at 0xa793140bc8>, <simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa793140b08>}
# keep resources []
# release destination : {<simpy.resources.resource.Resource object at 0x000000A792D4E4C8>: <Request() object at 0xa793140b08>}
# released origin : {}
# released processor : {}
# {}
# Activity end(Transfer TP)
# Activity end(Single run process)
# condition event triggered: True True round 9
# while loop requested_resources {}
# while loop keep_resources []

# %%
objects = [aeolus]

activities = []
for obj in objects:
    activities.extend(set(obj.log["Message"]))

activities = list(set(activities))

timestamps = []
logs = [o.log["Timestamp"] for o in objects]
for log in logs:
    timestamps.extend(log)

fig = vessel_planning(objects, activities, static=True, y_scale="numbers")

fig.add_scatter(
    x=[min(timestamps), max(timestamps)],
    y=[sailing_crit_empty.maximum,sailing_crit_empty.maximum], 
    mode='lines',
    name= "Sailing empty limit"
)

fig.add_scatter(
    x=[min(timestamps), max(timestamps)],
    y=[sailing_crit_full.maximum,sailing_crit_full.maximum], 
    mode='lines',
    name= "Sailing full limit"
)

fig.add_scatter(
    x=[min(timestamps), 
       max(timestamps)], 
    y=[loading_crit.maximum,loading_crit.maximum], 
    mode='lines', 
    name= "Loading limit"
)

fig.add_scatter(
    x=[min(timestamps), 
       max(timestamps)], 
    y=[installing_crit.maximum,installing_crit.maximum], 
    mode='lines', 
    name= "Installing limit"
)

fig.add_scatter(x=metocean_df["DateTime"], y=metocean_df["Hs [m]"], mode='lines', name = "Hs [m]")
# Out:
# <div>
#
#
#             <div id="3080c3db-2b56-4864-930d-140816fc57f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3080c3db-2b56-4864-930d-140816fc57f7")) {
#                     Plotly.newPlot(
#                         '3080c3db-2b56-4864-930d-140816fc57f7',
#                         [{"connectgaps": false, "hoverinfo": "y+name", "line": {"color": "rgb(119,135,55)", "width": 10}, "mode": "lines", "name": "sailing empty", "type": "scatter", "x": ["2020-03-01T00:00:00", "2020-03-01T00:00:00", "2020-03-01T00:00:00", "2020-03-01T00:00:00", "2020-03-01T00:00:00", "2020-03-02T10:52:20.644759", "2020-03-02T10:52:20.644759", "2020-03-02T16:29:14.407931", "2020-03-02T16:29:14.407931", "2020-03-02T16:29:14.407931", "2020-03-03T14:54:35.052690", "2020-03-03T14:54:35.052690", "2020-03-03T20:31:28.815863", "2020-03-03T20:31:28.815863", "2020-03-03T20:31:28.815863", "2020-03-04T20:32:20.644758", "2020-03-04T20:32:20.644758", "2020-03-05T02:09:14.407931", "2020-03-05T02:09:14.407931", "2020-03-05T02:09:14.407931", "2020-03-06T16:16:00", "2020-03-06T16:16:00", "2020-03-06T21:52:53.763172", "2020-03-06T21:52:53.763172", "2020-03-06T21:52:53.763172", "2020-03-07T20:18:14.407931", "2020-03-07T20:18:14.407931", "2020-03-08T01:55:08.171104", "2020-03-08T01:55:08.171104", "2020-03-08T01:55:08.171104", "2020-03-09T15:00:20.644758", "2020-03-09T15:00:20.644758", "2020-03-09T20:37:14.407931", "2020-03-09T20:37:14.407931", "2020-03-09T20:37:14.407931", "2020-03-10T19:02:35.052690", "2020-03-10T19:02:35.052690", "2020-03-11T00:39:28.815862", "2020-03-11T00:39:28.815862", "2020-03-11T00: